# %%
import requests
from bs4 import BeautifulSoup
from transformers import pipeline
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

def fetch_news_headlines(url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print("Error fetching news, status code:", response.status_code)
        return []

    soup = BeautifulSoup(response.content, 'html.parser')
    # For Inshorts, headlines are in <span> tags with attribute itemprop="headline"
    headline_elements = soup.find_all("span", {"itemprop": "headline"})
    headlines = [element.get_text(strip=True) for element in headline_elements]
    return headlines

def analyze_sentiments(headlines):

    sentiment_pipeline = pipeline("sentiment-analysis",
                                  model="distilbert-base-uncased-finetuned-sst-2-english")
    sentiments = sentiment_pipeline(headlines)
    return sentiments

def generate_word_cloud(text_list):

    text = " ".join(text_list)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title("Word Cloud of News Headlines")
    plt.show()

def plot_sentiment_distribution(sentiments):

    # Extract sentiment labels from the results
    labels = [result['label'] for result in sentiments]
    sentiment_counts = Counter(labels)

    # Prepare data for plotting
    labels_list, counts = zip(*sentiment_counts.items())

    # Color bars based on sentiment (green for positive, red for negative)
    colors = ['green' if label.upper() == 'POSITIVE' else 'red' for label in labels_list]

    plt.figure(figsize=(8, 5))
    plt.bar(labels_list, counts, color=colors)
    plt.xlabel("Sentiment")
    plt.ylabel("Number of Headlines")
    plt.title("Sentiment Distribution of News Headlines")
    plt.show()

def main():
    # URL for Inshorts news headlines (ensure scraping is permitted for educational use)
    url = "https://inshorts.com/en/read"
    headlines = fetch_news_headlines(url)

    if not headlines:
        print("No headlines found. Please check the URL or HTML selectors.")
        return

    sentiments = analyze_sentiments(headlines)

    # Print each headline with its corresponding sentiment result
    for headline, sentiment in zip(headlines, sentiments):
        print("Headline:", headline)
        print("Sentiment:", sentiment)
        print("-" * 80)

    # Visualization 1: Word Cloud of headlines
    generate_word_cloud(headlines)

    # Visualization 2: Bar chart of sentiment distribution
    plot_sentiment_distribution(sentiments)

if __name__ == "__main__":
    main()
# Out:
# Device set to use cpu
# Headline: Anushka Sharma reacts after Virat Kohli smashes hundred against Pakistan
# Sentiment: {'label': 'NEGATIVE', 'score': 0.606312096118927}
# --------------------------------------------------------------------------------
# Headline: Ukraine President Zelenskyy responds after Trump calls him 'dictator'
# Sentiment: {'label': 'POSITIVE', 'score': 0.8411927819252014}
# --------------------------------------------------------------------------------
# Headline: Bomb threat on flight from US to Delhi: Reports
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9824599027633667}
# --------------------------------------------------------------------------------
# Headline: Virat Kohli smashes an ODI hundred after 465 days, registers 82nd international ton
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9826918244361877}
# --------------------------------------------------------------------------------
# Headline: India defeat Pakistan for 5th time in a row as Virat Kohli smashes multiple records
# Sentiment: {'label': 'POSITIVE', 'score': 0.9986910223960876}
# --------------------------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
from transformers import pipeline
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
import time  # To add delays between requests

def fetch_news_headlines():

    base_url = "https://inshorts.com/en/read"
    headlines = []
    categories = ["all", "technology", "sports", "entertainment", "business"]  # Change categories if needed

    for category in categories:
        page = 1
        while page <= 3:  # Fetch 3 pages per category
            print(f"Fetching {category} - Page {page}...")
            url = f"https://inshorts.com/en/read/{category}"
            headers = {'User-Agent': 'Mozilla/5.0'}
            response = requests.get(url, headers=headers)

            if response.status_code != 200:
                print("Error fetching news, status code:", response.status_code)
                break  # Stop if there's an issue

            soup = BeautifulSoup(response.content, 'html.parser')
            headline_elements = soup.find_all("span", {"itemprop": "headline"})
            new_headlines = [element.get_text(strip=True) for element in headline_elements]

            if not new_headlines:
                break  # Stop if no new headlines found (pagination limit reached)

            headlines.extend(new_headlines)
            page += 1
            time.sleep(2)  # Avoid rate-limiting

    return headlines

def analyze_sentiments(headlines):

    sentiment_pipeline = pipeline("sentiment-analysis",
                                  model="distilbert-base-uncased-finetuned-sst-2-english")
    sentiments = sentiment_pipeline(headlines)
    return sentiments

def generate_word_cloud(text_list):

    text = " ".join(text_list)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title("Word Cloud of News Headlines")
    plt.show()

def plot_sentiment_distribution(sentiments):

    labels = [result['label'] for result in sentiments]
    sentiment_counts = Counter(labels)

    labels_list, counts = zip(*sentiment_counts.items())
    colors = ['green' if label.upper() == 'POSITIVE' else 'red' for label in labels_list]

    plt.figure(figsize=(8, 5))
    plt.bar(labels_list, counts, color=colors)
    plt.xlabel("Sentiment")
    plt.ylabel("Number of Headlines")
    plt.title("Sentiment Distribution of News Headlines")
    plt.show()

def main():
    headlines = fetch_news_headlines()

    if not headlines:
        print("No headlines found. Please check the URL or HTML selectors.")
        return

    sentiments = analyze_sentiments(headlines)

    # Print each headline with its corresponding sentiment result
    for headline, sentiment in zip(headlines, sentiments):
        print("Headline:", headline)
        print("Sentiment:", sentiment)
        print("-" * 80)

    # Visualization
    generate_word_cloud(headlines)
    plot_sentiment_distribution(sentiments)

if __name__ == "__main__":
    main()
# Out:
# Fetching all - Page 1...
# Fetching all - Page 2...
# Fetching all - Page 3...
# Fetching technology - Page 1...
# Fetching technology - Page 2...
# Fetching technology - Page 3...
# Fetching sports - Page 1...
# Fetching sports - Page 2...
# Fetching sports - Page 3...
# Fetching entertainment - Page 1...
# Fetching entertainment - Page 2...
# Fetching entertainment - Page 3...
# Fetching business - Page 1...
# Fetching business - Page 2...
# Fetching business - Page 3...
# Device set to use cpu
# Headline: The Beautiful Craft of Chandi Tarakasi
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998045563697815}
# --------------------------------------------------------------------------------
# Headline: When "The Beatles" visited India in 1968
# Sentiment: {'label': 'POSITIVE', 'score': 0.9922457337379456}
# --------------------------------------------------------------------------------
# Headline: Sajan Prakash and Karnataka teams break National Games records
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995662569999695}
# --------------------------------------------------------------------------------
# Headline: All about the Carpet Weaving technique of Sikkim
# Sentiment: {'label': 'POSITIVE', 'score': 0.9944156408309937}
# --------------------------------------------------------------------------------
# Headline: Kishore Kumar Jena opens up on challenging period
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995786547660828}
# --------------------------------------------------------------------------------
# Headline: Roopkund: The Lake of Skeletons in Himalayas
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9577173590660095}
# --------------------------------------------------------------------------------
# Headline: Charminar: The Pride of Hyderabad
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997947812080383}
# --------------------------------------------------------------------------------
# Headline: Sumit Antil looked up to Neeraj Chopra for inspiration
# Sentiment: {'label': 'POSITIVE', 'score': 0.9965617060661316}
# --------------------------------------------------------------------------------
# Headline: Mamaearth IPO subscribed 7.61 times on final day
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9865769147872925}
# --------------------------------------------------------------------------------
# Headline: Mohammed Shami's 5-wicket haul guides India to CWC'23 semifinals
# Sentiment: {'label': 'POSITIVE', 'score': 0.9990925788879395}
# --------------------------------------------------------------------------------
# Headline: The Beautiful Craft of Chandi Tarakasi
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998045563697815}
# --------------------------------------------------------------------------------
# Headline: When "The Beatles" visited India in 1968
# Sentiment: {'label': 'POSITIVE', 'score': 0.9922457337379456}
# --------------------------------------------------------------------------------
# Headline: Sajan Prakash and Karnataka teams break National Games records
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995662569999695}
# --------------------------------------------------------------------------------
# Headline: All about the Carpet Weaving technique of Sikkim
# Sentiment: {'label': 'POSITIVE', 'score': 0.9944156408309937}
# --------------------------------------------------------------------------------
# Headline: Kishore Kumar Jena opens up on challenging period
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995786547660828}
# --------------------------------------------------------------------------------
# Headline: Roopkund: The Lake of Skeletons in Himalayas
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9577173590660095}
# --------------------------------------------------------------------------------
# Headline: Charminar: The Pride of Hyderabad
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997947812080383}
# --------------------------------------------------------------------------------
# Headline: Sumit Antil looked up to Neeraj Chopra for inspiration
# Sentiment: {'label': 'POSITIVE', 'score': 0.9965617060661316}
# --------------------------------------------------------------------------------
# Headline: Mamaearth IPO subscribed 7.61 times on final day
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9865769147872925}
# --------------------------------------------------------------------------------
# Headline: Mohammed Shami's 5-wicket haul guides India to CWC'23 semifinals
# Sentiment: {'label': 'POSITIVE', 'score': 0.9990925788879395}
# --------------------------------------------------------------------------------
# Headline: The Beautiful Craft of Chandi Tarakasi
# Sentiment: {'label': 'POSITIVE', 'score': 0.9998045563697815}
# --------------------------------------------------------------------------------
# Headline: When "The Beatles" visited India in 1968
# Sentiment: {'label': 'POSITIVE', 'score': 0.9922457337379456}
# --------------------------------------------------------------------------------
# Headline: Sajan Prakash and Karnataka teams break National Games records
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995662569999695}
# --------------------------------------------------------------------------------
# Headline: All about the Carpet Weaving technique of Sikkim
# Sentiment: {'label': 'POSITIVE', 'score': 0.9944156408309937}
# --------------------------------------------------------------------------------
# Headline: Kishore Kumar Jena opens up on challenging period
# Sentiment: {'label': 'POSITIVE', 'score': 0.9995786547660828}
# --------------------------------------------------------------------------------
# Headline: Roopkund: The Lake of Skeletons in Himalayas
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9577173590660095}
# --------------------------------------------------------------------------------
# Headline: Charminar: The Pride of Hyderabad
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997947812080383}
# --------------------------------------------------------------------------------
# Headline: Sumit Antil looked up to Neeraj Chopra for inspiration
# Sentiment: {'label': 'POSITIVE', 'score': 0.9965617060661316}
# --------------------------------------------------------------------------------
# Headline: Mamaearth IPO subscribed 7.61 times on final day
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9865769147872925}
# --------------------------------------------------------------------------------
# Headline: Mohammed Shami's 5-wicket haul guides India to CWC'23 semifinals
# Sentiment: {'label': 'POSITIVE', 'score': 0.9990925788879395}
# --------------------------------------------------------------------------------
# Headline: Elon Musk's 2022 post supporting Ukraine resurfaces, he responds
# Sentiment: {'label': 'POSITIVE', 'score': 0.993304431438446}
# --------------------------------------------------------------------------------
# Headline: Video shows flying car worth ₹2.6 crore soaring over vehicle in first test
# Sentiment: {'label': 'POSITIVE', 'score': 0.9792913794517517}
# --------------------------------------------------------------------------------
# Headline: US reveals first-ever image of secretive X-37B space plane
# Sentiment: {'label': 'POSITIVE', 'score': 0.9979140162467957}
# --------------------------------------------------------------------------------
# Headline: Leaked chats show Ashley wanted to 'baby trap' Elon Musk; billionaire reacts
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9959710240364075}
# --------------------------------------------------------------------------------
# Headline: $300,000 flying car takes first flight, stuns internet
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9958107471466064}
# --------------------------------------------------------------------------------
# Headline: Musk mocks Parag Agrawal amid 'report work or resign' mail, says 'He got nothing done, was fired'
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9992629885673523}
# --------------------------------------------------------------------------------
# Headline: Despite global layoffs, Meta is hiring in India
# Sentiment: {'label': 'POSITIVE', 'score': 0.976150393486023}
# --------------------------------------------------------------------------------
# Headline: Apple bans 135,000 apps from App Store in biggest crackdown ever
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9990795850753784}
# --------------------------------------------------------------------------------
# Headline: Sam Altman and husband Oliver Mulherin welcome baby boy
# Sentiment: {'label': 'POSITIVE', 'score': 0.9996131062507629}
# --------------------------------------------------------------------------------
# Headline: Ashley, who claims she has a son with Musk, shares alleged texts by Musk
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9861590266227722}
# --------------------------------------------------------------------------------
# Headline: Elon Musk's 2022 post supporting Ukraine resurfaces, he responds
# Sentiment: {'label': 'POSITIVE', 'score': 0.993304431438446}
# --------------------------------------------------------------------------------
# Headline: Video shows flying car worth ₹2.6 crore soaring over vehicle in first test
# Sentiment: {'label': 'POSITIVE', 'score': 0.9792913794517517}
# --------------------------------------------------------------------------------
# Headline: US reveals first-ever image of secretive X-37B space plane
# Sentiment: {'label': 'POSITIVE', 'score': 0.9979140162467957}
# --------------------------------------------------------------------------------
# Headline: Leaked chats show Ashley wanted to 'baby trap' Elon Musk; billionaire reacts
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9959710240364075}
# --------------------------------------------------------------------------------
# Headline: $300,000 flying car takes first flight, stuns internet
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9958107471466064}
# --------------------------------------------------------------------------------
# Headline: Musk mocks Parag Agrawal amid 'report work or resign' mail, says 'He got nothing done, was fired'
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9992629885673523}
# --------------------------------------------------------------------------------
# Headline: Despite global layoffs, Meta is hiring in India
# Sentiment: {'label': 'POSITIVE', 'score': 0.976150393486023}
# --------------------------------------------------------------------------------
# Headline: Apple bans 135,000 apps from App Store in biggest crackdown ever
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9990795850753784}
# --------------------------------------------------------------------------------
# Headline: Sam Altman and husband Oliver Mulherin welcome baby boy
# Sentiment: {'label': 'POSITIVE', 'score': 0.9996131062507629}
# --------------------------------------------------------------------------------
# Headline: Ashley, who claims she has a son with Musk, shares alleged texts by Musk
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9861590266227722}
# --------------------------------------------------------------------------------
# Headline: Elon Musk's 2022 post supporting Ukraine resurfaces, he responds
# Sentiment: {'label': 'POSITIVE', 'score': 0.993304431438446}
# --------------------------------------------------------------------------------
# Headline: Video shows flying car worth ₹2.6 crore soaring over vehicle in first test
# Sentiment: {'label': 'POSITIVE', 'score': 0.9792913794517517}
# --------------------------------------------------------------------------------
# Headline: US reveals first-ever image of secretive X-37B space plane
# Sentiment: {'label': 'POSITIVE', 'score': 0.9979140162467957}
# --------------------------------------------------------------------------------
# Headline: Leaked chats show Ashley wanted to 'baby trap' Elon Musk; billionaire reacts
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9959710240364075}
# --------------------------------------------------------------------------------
# Headline: $300,000 flying car takes first flight, stuns internet
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9958107471466064}
# --------------------------------------------------------------------------------
# Headline: Musk mocks Parag Agrawal amid 'report work or resign' mail, says 'He got nothing done, was fired'
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9992629885673523}
# --------------------------------------------------------------------------------
# Headline: Despite global layoffs, Meta is hiring in India
# Sentiment: {'label': 'POSITIVE', 'score': 0.976150393486023}
# --------------------------------------------------------------------------------
# Headline: Apple bans 135,000 apps from App Store in biggest crackdown ever
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9990795850753784}
# --------------------------------------------------------------------------------
# Headline: Sam Altman and husband Oliver Mulherin welcome baby boy
# Sentiment: {'label': 'POSITIVE', 'score': 0.9996131062507629}
# --------------------------------------------------------------------------------
# Headline: Ashley, who claims she has a son with Musk, shares alleged texts by Musk
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9861590266227722}
# --------------------------------------------------------------------------------
# Headline: What is New Zealand's head-to-head record against Bangladesh in ODIs?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9949443936347961}
# --------------------------------------------------------------------------------
# Headline: You'll die a low-life: Javed Akhtar to X user trolling his post on Kohli after India's win
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9986547231674194}
# --------------------------------------------------------------------------------
# Headline: I am in awe of his hard work: Rizwan after Kohli's hundred vs Pak
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997971653938293}
# --------------------------------------------------------------------------------
# Headline: I'm happy for India but cricket lost: Ajay Jadeja on Ind-Pak match
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9868916869163513}
# --------------------------------------------------------------------------------
# Headline: Virat Kohli ends century drought, celebrates with SKY's gesture
# Sentiment: {'label': 'POSITIVE', 'score': 0.9978979825973511}
# --------------------------------------------------------------------------------
# Headline: No concerns over form of top-order: BAN head coach
# Sentiment: {'label': 'NEGATIVE', 'score': 0.97984778881073}
# --------------------------------------------------------------------------------
# Headline: Khushdil Shah drops Shubman Gill in high-octane clash in Dubai
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9630318284034729}
# --------------------------------------------------------------------------------
# Headline: Not travelling to PAK a missed opportunity for IND: PCB chairman
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8499487042427063}
# --------------------------------------------------------------------------------
# Headline: Hardik Pandya enraged after Harshit Rana drops Rizwan's catch
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9951818585395813}
# --------------------------------------------------------------------------------
# Headline: Watch: Rana & Rizwan involved in shoulder-to-shoulder incident
# Sentiment: {'label': 'POSITIVE', 'score': 0.6324251294136047}
# --------------------------------------------------------------------------------
# Headline: What is New Zealand's head-to-head record against Bangladesh in ODIs?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9949443936347961}
# --------------------------------------------------------------------------------
# Headline: You'll die a low-life: Javed Akhtar to X user trolling his post on Kohli after India's win
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9986547231674194}
# --------------------------------------------------------------------------------
# Headline: I am in awe of his hard work: Rizwan after Kohli's hundred vs Pak
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997971653938293}
# --------------------------------------------------------------------------------
# Headline: I'm happy for India but cricket lost: Ajay Jadeja on Ind-Pak match
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9868916869163513}
# --------------------------------------------------------------------------------
# Headline: Virat Kohli ends century drought, celebrates with SKY's gesture
# Sentiment: {'label': 'POSITIVE', 'score': 0.9978979825973511}
# --------------------------------------------------------------------------------
# Headline: No concerns over form of top-order: BAN head coach
# Sentiment: {'label': 'NEGATIVE', 'score': 0.97984778881073}
# --------------------------------------------------------------------------------
# Headline: Khushdil Shah drops Shubman Gill in high-octane clash in Dubai
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9630318284034729}
# --------------------------------------------------------------------------------
# Headline: Not travelling to PAK a missed opportunity for IND: PCB chairman
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8499487042427063}
# --------------------------------------------------------------------------------
# Headline: Hardik Pandya enraged after Harshit Rana drops Rizwan's catch
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9951818585395813}
# --------------------------------------------------------------------------------
# Headline: Watch: Rana & Rizwan involved in shoulder-to-shoulder incident
# Sentiment: {'label': 'POSITIVE', 'score': 0.6324251294136047}
# --------------------------------------------------------------------------------
# Headline: What is New Zealand's head-to-head record against Bangladesh in ODIs?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9949443936347961}
# --------------------------------------------------------------------------------
# Headline: You'll die a low-life: Javed Akhtar to X user trolling his post on Kohli after India's win
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9986547231674194}
# --------------------------------------------------------------------------------
# Headline: I am in awe of his hard work: Rizwan after Kohli's hundred vs Pak
# Sentiment: {'label': 'POSITIVE', 'score': 0.9997971653938293}
# --------------------------------------------------------------------------------
# Headline: I'm happy for India but cricket lost: Ajay Jadeja on Ind-Pak match
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9868916869163513}
# --------------------------------------------------------------------------------
# Headline: Virat Kohli ends century drought, celebrates with SKY's gesture
# Sentiment: {'label': 'POSITIVE', 'score': 0.9978979825973511}
# --------------------------------------------------------------------------------
# Headline: No concerns over form of top-order: BAN head coach
# Sentiment: {'label': 'NEGATIVE', 'score': 0.97984778881073}
# --------------------------------------------------------------------------------
# Headline: Khushdil Shah drops Shubman Gill in high-octane clash in Dubai
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9630318284034729}
# --------------------------------------------------------------------------------
# Headline: Not travelling to PAK a missed opportunity for IND: PCB chairman
# Sentiment: {'label': 'NEGATIVE', 'score': 0.8499487042427063}
# --------------------------------------------------------------------------------
# Headline: Hardik Pandya enraged after Harshit Rana drops Rizwan's catch
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9951818585395813}
# --------------------------------------------------------------------------------
# Headline: Watch: Rana & Rizwan involved in shoulder-to-shoulder incident
# Sentiment: {'label': 'POSITIVE', 'score': 0.6324251294136047}
# --------------------------------------------------------------------------------
# Headline: No distributor wanted 'Baghban', Salman saved it: Renu Chopra
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6557207703590393}
# --------------------------------------------------------------------------------
# Headline: Felt responsible when 'The Archies' actors were trolled: Zoya
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9960643649101257}
# --------------------------------------------------------------------------------
# Headline: Indian Idol 15 criticised for inviting Udit Narayan after row over his kissing videos
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9913551211357117}
# --------------------------------------------------------------------------------
# Headline: Police complaint against Munawar's Hafta Vasooli for allegedly promoting vulgarity
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9974499344825745}
# --------------------------------------------------------------------------------
# Headline: Haven't received ₹50 lakh prize money yet: Karan on Bigg Boss 18
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9502114057540894}
# --------------------------------------------------------------------------------
# Headline: I think Boman was more terrified than I was: Azmi on kiss scene
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9904236197471619}
# --------------------------------------------------------------------------------
# Headline: Video shows Sunny Deol, Dhoni watching India-Pak CT match together
# Sentiment: {'label': 'POSITIVE', 'score': 0.5530850887298584}
# --------------------------------------------------------------------------------
# Headline: Mukundan loses cool, snatches fan's phone as latter records him
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9997113347053528}
# --------------------------------------------------------------------------------
# Headline: Jonathan Coachman claims Tony Khan ghosted Shane McMahon
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9874883890151978}
# --------------------------------------------------------------------------------
# Headline: Ind vs Pak: Chiranjeevi's reaction goes viral as Rohit gets out
# Sentiment: {'label': 'POSITIVE', 'score': 0.996299684047699}
# --------------------------------------------------------------------------------
# Headline: No distributor wanted 'Baghban', Salman saved it: Renu Chopra
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6557207703590393}
# --------------------------------------------------------------------------------
# Headline: Felt responsible when 'The Archies' actors were trolled: Zoya
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9960643649101257}
# --------------------------------------------------------------------------------
# Headline: Indian Idol 15 criticised for inviting Udit Narayan after row over his kissing videos
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9913551211357117}
# --------------------------------------------------------------------------------
# Headline: Police complaint against Munawar's Hafta Vasooli for allegedly promoting vulgarity
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9974499344825745}
# --------------------------------------------------------------------------------
# Headline: Haven't received ₹50 lakh prize money yet: Karan on Bigg Boss 18
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9502114057540894}
# --------------------------------------------------------------------------------
# Headline: I think Boman was more terrified than I was: Azmi on kiss scene
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9904236197471619}
# --------------------------------------------------------------------------------
# Headline: Video shows Sunny Deol, Dhoni watching India-Pak CT match together
# Sentiment: {'label': 'POSITIVE', 'score': 0.5530850887298584}
# --------------------------------------------------------------------------------
# Headline: Mukundan loses cool, snatches fan's phone as latter records him
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9997113347053528}
# --------------------------------------------------------------------------------
# Headline: Jonathan Coachman claims Tony Khan ghosted Shane McMahon
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9874883890151978}
# --------------------------------------------------------------------------------
# Headline: Ind vs Pak: Chiranjeevi's reaction goes viral as Rohit gets out
# Sentiment: {'label': 'POSITIVE', 'score': 0.996299684047699}
# --------------------------------------------------------------------------------
# Headline: No distributor wanted 'Baghban', Salman saved it: Renu Chopra
# Sentiment: {'label': 'NEGATIVE', 'score': 0.6557207703590393}
# --------------------------------------------------------------------------------
# Headline: Felt responsible when 'The Archies' actors were trolled: Zoya
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9960643649101257}
# --------------------------------------------------------------------------------
# Headline: Indian Idol 15 criticised for inviting Udit Narayan after row over his kissing videos
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9913551211357117}
# --------------------------------------------------------------------------------
# Headline: Police complaint against Munawar's Hafta Vasooli for allegedly promoting vulgarity
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9974499344825745}
# --------------------------------------------------------------------------------
# Headline: Haven't received ₹50 lakh prize money yet: Karan on Bigg Boss 18
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9502114057540894}
# --------------------------------------------------------------------------------
# Headline: I think Boman was more terrified than I was: Azmi on kiss scene
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9904236197471619}
# --------------------------------------------------------------------------------
# Headline: Video shows Sunny Deol, Dhoni watching India-Pak CT match together
# Sentiment: {'label': 'POSITIVE', 'score': 0.5530850887298584}
# --------------------------------------------------------------------------------
# Headline: Mukundan loses cool, snatches fan's phone as latter records him
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9997113347053528}
# --------------------------------------------------------------------------------
# Headline: Jonathan Coachman claims Tony Khan ghosted Shane McMahon
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9874883890151978}
# --------------------------------------------------------------------------------
# Headline: Ind vs Pak: Chiranjeevi's reaction goes viral as Rohit gets out
# Sentiment: {'label': 'POSITIVE', 'score': 0.996299684047699}
# --------------------------------------------------------------------------------
# Headline: CIL's subsidiary bids for 2 coal blocks in 11th tranche of auction
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9877312779426575}
# --------------------------------------------------------------------------------
# Headline: Why did the Indian stock market crash on Monday?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9991714954376221}
# --------------------------------------------------------------------------------
# Headline: Hazoor Multi Projects bags order worth ₹102.10 crore
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9861531257629395}
# --------------------------------------------------------------------------------
# Headline: Warehouse management system revenues to reach $10 bn by 2030
# Sentiment: {'label': 'NEGATIVE', 'score': 0.989931583404541}
# --------------------------------------------------------------------------------
# Headline: KKR acquires controlling stake in Healthcare Global Enterprises
# Sentiment: {'label': 'POSITIVE', 'score': 0.9901258945465088}
# --------------------------------------------------------------------------------
# Headline: Veranda Learning buys stakes in BB Virtuals and Navkar Digital
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7686769366264343}
# --------------------------------------------------------------------------------
# Headline: Trump's VAT-tariff comments raise concerns for Indian exports
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9228094220161438}
# --------------------------------------------------------------------------------
# Headline: Pfizer approves marketing and supply agreement with Mylan Pharma
# Sentiment: {'label': 'POSITIVE', 'score': 0.9943063855171204}
# --------------------------------------------------------------------------------
# Headline: Promoters buy 10,000 shares of Kilburn Engineering Ltd
# Sentiment: {'label': 'POSITIVE', 'score': 0.8071860671043396}
# --------------------------------------------------------------------------------
# Headline: Small and Mid-Cap indices show resilience amid market slump
# Sentiment: {'label': 'POSITIVE', 'score': 0.987701952457428}
# --------------------------------------------------------------------------------
# Headline: CIL's subsidiary bids for 2 coal blocks in 11th tranche of auction
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9877312779426575}
# --------------------------------------------------------------------------------
# Headline: Why did the Indian stock market crash on Monday?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9991714954376221}
# --------------------------------------------------------------------------------
# Headline: Hazoor Multi Projects bags order worth ₹102.10 crore
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9861531257629395}
# --------------------------------------------------------------------------------
# Headline: Warehouse management system revenues to reach $10 bn by 2030
# Sentiment: {'label': 'NEGATIVE', 'score': 0.989931583404541}
# --------------------------------------------------------------------------------
# Headline: KKR acquires controlling stake in Healthcare Global Enterprises
# Sentiment: {'label': 'POSITIVE', 'score': 0.9901258945465088}
# --------------------------------------------------------------------------------
# Headline: Veranda Learning buys stakes in BB Virtuals and Navkar Digital
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7686769366264343}
# --------------------------------------------------------------------------------
# Headline: Trump's VAT-tariff comments raise concerns for Indian exports
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9228094220161438}
# --------------------------------------------------------------------------------
# Headline: Pfizer approves marketing and supply agreement with Mylan Pharma
# Sentiment: {'label': 'POSITIVE', 'score': 0.9943063855171204}
# --------------------------------------------------------------------------------
# Headline: Promoters buy 10,000 shares of Kilburn Engineering Ltd
# Sentiment: {'label': 'POSITIVE', 'score': 0.8071860671043396}
# --------------------------------------------------------------------------------
# Headline: Small and Mid-Cap indices show resilience amid market slump
# Sentiment: {'label': 'POSITIVE', 'score': 0.987701952457428}
# --------------------------------------------------------------------------------
# Headline: CIL's subsidiary bids for 2 coal blocks in 11th tranche of auction
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9877312779426575}
# --------------------------------------------------------------------------------
# Headline: Why did the Indian stock market crash on Monday?
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9991714954376221}
# --------------------------------------------------------------------------------
# Headline: Hazoor Multi Projects bags order worth ₹102.10 crore
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9861531257629395}
# --------------------------------------------------------------------------------
# Headline: Warehouse management system revenues to reach $10 bn by 2030
# Sentiment: {'label': 'NEGATIVE', 'score': 0.989931583404541}
# --------------------------------------------------------------------------------
# Headline: KKR acquires controlling stake in Healthcare Global Enterprises
# Sentiment: {'label': 'POSITIVE', 'score': 0.9901258945465088}
# --------------------------------------------------------------------------------
# Headline: Veranda Learning buys stakes in BB Virtuals and Navkar Digital
# Sentiment: {'label': 'NEGATIVE', 'score': 0.7686769366264343}
# --------------------------------------------------------------------------------
# Headline: Trump's VAT-tariff comments raise concerns for Indian exports
# Sentiment: {'label': 'NEGATIVE', 'score': 0.9228094220161438}
# --------------------------------------------------------------------------------
# Headline: Pfizer approves marketing and supply agreement with Mylan Pharma
# Sentiment: {'label': 'POSITIVE', 'score': 0.9943063855171204}
# --------------------------------------------------------------------------------
# Headline: Promoters buy 10,000 shares of Kilburn Engineering Ltd
# Sentiment: {'label': 'POSITIVE', 'score': 0.8071860671043396}
# --------------------------------------------------------------------------------
# Headline: Small and Mid-Cap indices show resilience amid market slump
# Sentiment: {'label': 'POSITIVE', 'score': 0.987701952457428}
# --------------------------------------------------------------------------------
